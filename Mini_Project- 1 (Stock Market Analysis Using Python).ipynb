# %% [markdown]
# **Objective:** Use Python libraries such as Pandas, Seaborn, and Matplotlib to extract and analyze
# the information, visualize it, and look at different ways to analyze the risk of a stock, based on its
# performance history.
#
# **About the Data:** The stocks we have chosen are from various industries and market caps namely,
# - Apple
# - Google
# - Microsoft
# - Amazon
#
# For the start, we shall investigate the Amazon stock individually and then move on to the
# combined analysis.
# To know more about stocks and their data please visit the below link:
# **https://in.finance.yahoo.com/**

# %% [markdown]
# **The following tasks are to be performed:**
#
# __1- Read the Data from Yahoo finance website directly.__
#
# __2- Perform cleaning.__
#
# __3- What was the change in stock price over time?__
#
# __4- Visualize the change in a stock’s volume being traded, over time?__
#
# __5- What was the moving average of various stocks?__
#
# __6- What was the daily return average of a stock?__
#
# __7- Add a new column ‘Trend’ whose values are based on the 'Daily Return'.__
#
# __8- Visualize trend frequency through a Pie Chart.__
#
# __9- What was the correlation between the daily returns of different stocks?__mm

# %% [markdown]
# # We First investigate the Amazon stock individually and then move on to the combined analysis.

# %% [markdown]
# # Task-1:-
#
# **Read the Data from Yahoo finance website directly.**

# %%
# Step-1:- Importing yfinance and pandas library.

import yfinance as yf
import pandas as pd

# %%
# Step-2:- Importing the Amazon stock

# Create a Ticker object for Amazon (AMZN)  
Amazon = yf.Ticker("AMZN")

# Download historical data for a specific period (adjust parameters as needed)
historical_data = Amazon.history(period="10y")

# Convert the historical data to a DataFrame
Amazon_df = pd.DataFrame(historical_data)

# Viewing the Amazon record
Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# # Task-2:-
#
# **Perform cleaning.**

# %%
# Step-1:- Explore the Amazon Data:

print("Starting 50 records of Amazon Data are:- \n")
print(Amazon_df.head(50))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Ending 50 records of Amazon Data are:- :- \n")
print(Amazon_df.tail(50))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Amazon Data Information is :- \n")
print(Amazon_df.info())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Amazon Data Description is :- \n")
print(Amazon_df.describe(include = "all"))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Starting 50 records of Amazon Data are:-
#
#                                 Open       High        Low      Close  \
# Date
# 2013-11-25 00:00:00-05:00  18.691000  18.889500  18.659000  18.832001
# 2013-11-26 00:00:00-05:00  18.880501  19.125000  18.740999  19.068501
# 2013-11-27 00:00:00-05:00  19.174999  19.350000  19.130501  19.335501
# 2013-11-29 00:00:00-05:00  19.455000  19.705000  19.431000  19.681000
# 2013-12-02 00:00:00-05:00  19.950001  19.950001  19.455000  19.615000
# 2013-12-03 00:00:00-05:00  19.505501  19.547501  19.155001  19.233000
# 2013-12-04 00:00:00-05:00  19.174999  19.484501  19.074499  19.298000
# 2013-12-05 00:00:00-05:00  19.332500  19.332500  19.068501  19.224501
# 2013-12-06 00:00:00-05:00  19.417500  19.417500  19.191500  19.347500
# 2013-12-09 00:00:00-05:00  19.405500  19.410500  19.128500  19.244499
# 2013-12-10 00:00:00-05:00  19.187000  19.452999  19.150999  19.389000
# 2013-12-11 00:00:00-05:00  19.367001  19.448999  19.100000  19.109501
# ...

# %%
# Step-2:- Attributes of Amazon Data:

print("Checking the datatype of each and every column present in our Amazon Data:- \n")
print(Amazon_df.dtypes)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the Columns of Amazon Data:- \n")
print(Amazon_df.columns)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the no.of rows and no.of columns present in our Amazon Data:- \n")
print(Amazon_df.shape)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the Total no. of elements present in our Amazon Data:- \n")
print(Amazon_df.size)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the total no. of dimensions present in our Amazon Data:- \n")
print(Amazon_df.ndim)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the details of both the row and column labels in our Amazon Data:- \n")
print(Amazon_df.axes)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the datatype of each and every column present in our Amazon Data:-
#
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Checking the Columns of Amazon Data:-
#
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Checking the no.of rows and no.of columns present in our Amazon Data:-
#
# (2517, 7)
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Checking the Total no. of elements present in our Amazon Data:-
#
# 17619
#
#
# ...

# %%
# Step-3:- Handling Null/Missing Data:

print("Checking the missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#                             Open   High    Low  Close  Volume  Dividends  \
# Date
# 2013-11-25 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-26 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-27 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-29 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-02 00:00:00-05:00  False  False  False  False   False      False
# ...                          ...    ...    ...    ...     ...        ...
# 2023-11-17 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-20 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-21 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-22 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-24 00:00:00-05:00  False  False  False  False   False      False
#
# ...

# %% [markdown]
# **It Seems like there is no null/missing value present in our Amazon Data**

# %%
# Step-4:- Handling Duplicates:

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df[Amazon_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-25 00:00:00-05:00    False
# 2013-11-26 00:00:00-05:00    False
# 2013-11-27 00:00:00-05:00    False
# 2013-11-29 00:00:00-05:00    False
# 2013-12-02 00:00:00-05:00    False
#                              ...
# 2023-11-17 00:00:00-05:00    False
# 2023-11-20 00:00:00-05:00    False
# 2023-11-21 00:00:00-05:00    False
# 2023-11-22 00:00:00-05:00    False
# 2023-11-24 00:00:00-05:00    False
# Length: 2517, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Dividends, Stock Splits]
# Index: []
#
#
# ...

# %% [markdown]
# **It Seems like there is no Duplicates value present in our Amazon Data**

# %%
# Step-5:- Droping two columns "Dividends" and "Stock Splits" because there is no data 

print("Viewing our Amazon Data Before Droping the columns:- \n")
print(Amazon_df)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

Amazon_df.drop("Dividends", axis=1, inplace = True)
Amazon_df.drop("Stock Splits", axis=1, inplace = True)

print("Viewing our Amazon Data After Droping the columns:- \n")
print(Amazon_df)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Viewing our Amazon Data Before Droping the columns:-
#
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
# ...

# %% [markdown]
# **Our Amazon Data is now cleaned and ready for the other tasks.**

# %% [markdown]
# # Task-3:-
#
# **What was the change in stock price over time?**

# %%
# Step-1:- Calculate the stock price changes over Time.
print("Viewing our Amazon Data Before Calculate the stock price changes over time:- \n")
print(Amazon_df)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")


# Step-2:- Calculate the stock price.
Amazon_df["Over time"] = Amazon_df["Close"].diff()

print("Viewing our Amazon Data After Calculate the stock price changes over time:- \n")
print(Amazon_df)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Viewing our Amazon Data Before Calculate the stock price changes over time:-
#
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# ...

# %% [markdown]
# # Task-4:-
#
# **Visualize the change in a stock’s volume being traded, over time?**

# %%
# Step-1:- Viewing the Amazon record Before Replacing with Nan Value:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time
# Date
# ...

# %%
# Step-2:- Handling Null/Missing Data:

print("Checking the missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#                             Open   High    Low  Close  Volume  Over time
# Date
# 2013-11-25 00:00:00-05:00  False  False  False  False   False       True
# 2013-11-26 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-27 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-29 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-02 00:00:00-05:00  False  False  False  False   False      False
# ...                          ...    ...    ...    ...     ...        ...
# 2023-11-17 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-20 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-21 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-22 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-24 00:00:00-05:00  False  False  False  False   False      False
#
# [2517 rows x 6 columns]
#
#
# ...

# %% [markdown]
# **It shows here is a null/nan value present in our Amazon record after createing our Over time Column.**

# %%
# Step-3:- Checking the mode value of our Over Time column.

Amazon_df["Over time"].mode()[0]
# Out:
# -0.16899871826171875

# %%
# Step-4:- Now Replacing our Nan value with our Mode value :

Amazon_df["Over time"].fillna(Amazon_df["Over time"].mode()[0],inplace=True)

# %%
# Step-5:- Viewing the Amazon record After Replacing with Nan Value: 

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time
# Date
# ...

# %%
# Step-6:- Now we are going to Visualize the change in a stock’s volume being traded over time:

import matplotlib.pyplot as plt
import pandas as pd

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(Amazon_df.index, Amazon_df['Volume'], marker='o', linestyle='-', color='g')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True, color="r")

plt.show()

# %% [markdown]
# # Task-5:-
#
# **What was the moving average of various stocks?**

# %%
# Step-1:- Viewing the Amazon record Before Creating the moving average:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time
# Date
# ...

# %%
# Step-2:- The moving average of various stocks are:

Amazon_df['10-Day MA']=Amazon_df['Close'].rolling(window=10).mean()
Amazon_df['50-Day MA']=Amazon_df['Close'].rolling(window=50).mean()

# %%
# Step-3:- Viewing the Amazon record After Creating the moving average:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA
# ...

# %% [markdown]
# **It shows here is a null/nan value present in our Amazon record after createing our "10-Day MA", "50-Day MA" Column.**

# %%
# Step-4:- calculate null value present in our column "10-Day MA","50-Day MA":

print("Checking the missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#                             Open   High    Low  Close  Volume  Over time  \
# Date
# 2013-11-25 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-26 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-27 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-29 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-02 00:00:00-05:00  False  False  False  False   False      False
# ...                          ...    ...    ...    ...     ...        ...
# 2023-11-17 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-20 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-21 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-22 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-24 00:00:00-05:00  False  False  False  False   False      False
#
# ...

# %%
# Step-5:- calculate Duplicates value present in our column "10-Day MA","50-Day MA":

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df[Amazon_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-25 00:00:00-05:00    False
# 2013-11-26 00:00:00-05:00    False
# 2013-11-27 00:00:00-05:00    False
# 2013-11-29 00:00:00-05:00    False
# 2013-12-02 00:00:00-05:00    False
#                              ...
# 2023-11-17 00:00:00-05:00    False
# 2023-11-20 00:00:00-05:00    False
# 2023-11-21 00:00:00-05:00    False
# 2023-11-22 00:00:00-05:00    False
# 2023-11-24 00:00:00-05:00    False
# Length: 2517, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Over time, 10-Day MA, 50-Day MA]
# Index: []
#
#
# ...

# %%
# Step-6:- viewing our record before changing the null values .

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA
# ...

# %%
# Step-7:- Checking the mode value of our 10-Day MA column.

Amazon_df["10-Day MA"].mode()[0]
# Out:
# 133.98699951171875

# %%
# Step-8:- Now Replacing our Nan value with our Mode value :

Amazon_df["10-Day MA"].fillna(Amazon_df["10-Day MA"].mode()[0],inplace=True)

# %%
# Step-9:- Checking the mode value of our 50-Day MA column.

Amazon_df["50-Day MA"].mode()[0]
# Out:
# 15.670580005645752

# %%
# Step-10:- Now Replacing our Nan value with our Mode value :

Amazon_df["50-Day MA"].fillna(Amazon_df["50-Day MA"].mode()[0],inplace=True)

# %%
# Step-11:- Viewing the Amazon record After Replacing with Nan Value: 

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA
# ...

# %% [markdown]
# # Task-6:-
#
# **What was the daily return average of a stock?**

# %%
# Step-1:- Now Viewing our Amazon data before adding the daily return column:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA
# ...

# %%
# Step-2:- Now Creating Daily Return column:

Amazon_df['Daily_Return'] = Amazon_df['Close'].pct_change() * 100

# %%
# Step-3:- Now Viewing our Amazon data After adding the daily return column:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %%
# Step-4:- calculate null value present in our column Trend:

print("Checking the missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#                             Open   High    Low  Close  Volume  Over time  \
# Date
# 2013-11-25 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-26 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-27 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-29 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-02 00:00:00-05:00  False  False  False  False   False      False
# ...                          ...    ...    ...    ...     ...        ...
# 2023-11-17 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-20 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-21 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-22 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-24 00:00:00-05:00  False  False  False  False   False      False
#
# ...

# %%
# Step-5:- calculate Duplicates value present in our column Trend:

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df[Amazon_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-25 00:00:00-05:00    False
# 2013-11-26 00:00:00-05:00    False
# 2013-11-27 00:00:00-05:00    False
# 2013-11-29 00:00:00-05:00    False
# 2013-12-02 00:00:00-05:00    False
#                              ...
# 2023-11-17 00:00:00-05:00    False
# 2023-11-20 00:00:00-05:00    False
# 2023-11-21 00:00:00-05:00    False
# 2023-11-22 00:00:00-05:00    False
# 2023-11-24 00:00:00-05:00    False
# Length: 2517, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Over time, 10-Day MA, 50-Day MA, Daily_Return]
# Index: []
#
#
# ...

# %%
# Step-6:- viewing our record before changing the null values .

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-25 00:00:00-05:00   18.691000   18.889500   18.659000   18.832001
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %%
# Step-7:- Droping the nan value in our Amazon_df:

Amazon_df.dropna(inplace=True)

# %%
# Step-8:- Now Replacing our Nan value with our mean value :

Amazon_df.fillna(Amazon_df.mean(), inplace=True)

# %%
# Step-9:- Viewing the Amazon record After Replacing with Nan Value: 

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# 2013-12-03 00:00:00-05:00   19.505501   19.547501   19.155001   19.233000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %% [markdown]
# # Task-7:-
#
# **Add a new column ‘Trend’ whose values are based on the 'Daily Return'.**

# %%
# Step-1:- Now Viewing our Amazon data before adding the Trend column:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# 2013-12-03 00:00:00-05:00   19.505501   19.547501   19.155001   19.233000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %%
# Step-2: Calculate the values of Trend over Daily Return.

Amazon_df["Trend"] = Amazon_df["Daily_Return"].diff()

# %%
# Step-3:- Now Viewing our Amazon data before adding the Trend column:

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# 2013-12-03 00:00:00-05:00   19.505501   19.547501   19.155001   19.233000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %% [markdown]
# **It shows here is a null/nan value present in our Amazon record after createing our Trend Column.**

# %%
# Step-4:- calculate null value present in our column Trend:

print("Checking the missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(Amazon_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#                             Open   High    Low  Close  Volume  Over time  \
# Date
# 2013-11-26 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-27 00:00:00-05:00  False  False  False  False   False      False
# 2013-11-29 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-02 00:00:00-05:00  False  False  False  False   False      False
# 2013-12-03 00:00:00-05:00  False  False  False  False   False      False
# ...                          ...    ...    ...    ...     ...        ...
# 2023-11-17 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-20 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-21 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-22 00:00:00-05:00  False  False  False  False   False      False
# 2023-11-24 00:00:00-05:00  False  False  False  False   False      False
#
# ...

# %%
# Step-5:- calculate Duplicates value present in our column Trend:

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(Amazon_df[Amazon_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-26 00:00:00-05:00    False
# 2013-11-27 00:00:00-05:00    False
# 2013-11-29 00:00:00-05:00    False
# 2013-12-02 00:00:00-05:00    False
# 2013-12-03 00:00:00-05:00    False
#                              ...
# 2023-11-17 00:00:00-05:00    False
# 2023-11-20 00:00:00-05:00    False
# 2023-11-21 00:00:00-05:00    False
# 2023-11-22 00:00:00-05:00    False
# 2023-11-24 00:00:00-05:00    False
# Length: 2516, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Over time, 10-Day MA, 50-Day MA, Daily_Return, Trend]
# Index: []
#
#
# ...

# %%
# Step-6:- viewing our record before changing the null values .

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# 2013-12-03 00:00:00-05:00   19.505501   19.547501   19.155001   19.233000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %%
# Step-7:- Checking the mode value of our Trend column.

Amazon_df["Trend"].mode()[0]
# Out:
# -18.702856311357706

# %%
# Step-8:- Now Replacing our Nan value with our Mode value :

Amazon_df["Trend"].fillna(Amazon_df["Trend"].mode()[0],inplace=True)

# %%
# Step-9:- Viewing the Amazon record After Replacing with Nan Value: 

Amazon_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-11-26 00:00:00-05:00   18.880501   19.125000   18.740999   19.068501
# 2013-11-27 00:00:00-05:00   19.174999   19.350000   19.130501   19.335501
# 2013-11-29 00:00:00-05:00   19.455000   19.705000   19.431000   19.681000
# 2013-12-02 00:00:00-05:00   19.950001   19.950001   19.455000   19.615000
# 2013-12-03 00:00:00-05:00   19.505501   19.547501   19.155001   19.233000
# ...                               ...         ...         ...         ...
# 2023-11-17 00:00:00-05:00  142.660004  145.229996  142.539993  145.179993
# 2023-11-20 00:00:00-05:00  145.130005  146.630005  144.729996  146.130005
# 2023-11-21 00:00:00-05:00  143.910004  144.050003  141.500000  143.899994
# 2023-11-22 00:00:00-05:00  144.570007  147.740005  144.570007  146.710007
# 2023-11-24 00:00:00-05:00  146.699997  147.199997  145.330002  146.823303
#
#                              Volume  Over time   10-Day MA   50-Day MA  \
# ...

# %% [markdown]
# # Task-8:-
#
# **Visualize trend frequency through a Pie Chart.**

# %%
# Step-1:- Now Changing the Trend columns value to "Stable", "High" and "Low":

Amazon_df['Trend'] = 'Stable'
Amazon_df.loc[Amazon_df['Daily_Return'] > 0, 'Trend'] = 'High'
Amazon_df.loc[Amazon_df['Daily_Return'] < 0, 'Trend'] = 'Low'

# %%
# Step-2:- Visualize trend frequency through a Pie Chart:

# Calculate trend frequencies
trend_counts = Amazon_df['Trend'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=140, shadow = True)

# Add a legend
plt.legend(trend_counts.index, title='Trends', loc='upper right')

# Add a title
plt.title('Trend Frequencies')

# Show the pie chart
plt.show()

# %% [markdown]
# # End of investigate the Amazon stock individually and now we are move on to the combined analysis.

# %% [markdown]
# # Now we are move on to the combined analysis of Stocks like:-
#
# -  **Apple**
# - **Google**
# - **Microsoft**
# - **Amazon**

# %% [markdown]
# # Task-1:-
#
# **Read the Data from Yahoo finance website directly.**

# %%
# Step-1:- Importing yfinance and pandas library:

import yfinance as yf
import pandas as pd

# %%
# Step-2:- Importing the "Apple", "Google", "Microsoft" and "Amazon stock":

# Define a list of stock tickers
stock_tickers = ['AAPL', 'GOOGL', 'MSFT', 'AMZN']

# Download stock data for the specified tickers with a specified period
stock_data = yf.download(stock_tickers, period='10y')

# Convert the historical data to a DataFrame
combined_data_df = pd.DataFrame(stock_data)

# Viewing the Amazon record
combined_data_df
# Out:
# [*********************100%%**********************]  4 of 4 completed
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-25   16.398518   18.832001   26.174423   31.695011   18.705000
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# ...

# %% [markdown]
# # Task-2:-
#
# **Perform cleaning.**

# %%
# Step-1:- Explore the combined_data_df:

print("Starting 50 records of Amazon Data are:- \n")
print(combined_data_df.head(50))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Ending 50 records of Amazon Data are:- :- \n")
print(combined_data_df.tail(50))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Amazon Data Information is :- \n")
print(combined_data_df.info())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Amazon Data Description is :- \n")
print(combined_data_df.describe(include = "all"))
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Starting 50 records of Amazon Data are:-
#
#             Adj Close                                       Close             \
#                  AAPL       AMZN      GOOGL       MSFT       AAPL       AMZN
# Date
# 2013-11-25  16.398518  18.832001  26.174423  31.695011  18.705000  18.832001
# 2013-11-26  16.700970  19.068501  26.486736  31.450815  19.049999  19.068501
# 2013-11-27  17.094231  19.335501  26.604355  31.661324  19.498571  19.335501
# 2013-11-29  17.410784  19.681000  26.516266  32.107613  19.859644  19.681000
# 2013-12-02  17.259233  19.615000  26.388388  32.377071  19.686787  19.615000
# 2013-12-03  17.731712  19.233000  26.357859  32.259182  20.225714  19.233000
# 2013-12-04  17.690386  19.298000  26.480982  32.789680  20.178572  19.298000
# 2013-12-05  17.781183  19.224501  26.459961  31.998140  20.282143  19.224501
# 2013-12-06  17.534454  19.347500  26.773523  32.301296  20.000713  19.347500
# ...

# %%
# Step-2:- Attributes of combined_data_df:

print("Checking the datatype of each and every column present in our Amazon Data:- \n")
print(combined_data_df.dtypes)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the Columns of Amazon Data:- \n")
print(combined_data_df.columns)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the no.of rows and no.of columns present in our Amazon Data:- \n")
print(combined_data_df.shape)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the Total no. of elements present in our Amazon Data:- \n")
print(combined_data_df.size)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the total no. of dimensions present in our Amazon Data:- \n")
print(combined_data_df.ndim)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Checking the details of both the row and column labels in our Amazon Data:- \n")
print(combined_data_df.axes)
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the datatype of each and every column present in our Amazon Data:-
#
# Adj Close  AAPL     float64
#            AMZN     float64
#            GOOGL    float64
#            MSFT     float64
# Close      AAPL     float64
#            AMZN     float64
#            GOOGL    float64
#            MSFT     float64
# High       AAPL     float64
#            AMZN     float64
#            GOOGL    float64
#            MSFT     float64
# Low        AAPL     float64
#            AMZN     float64
#            GOOGL    float64
#            MSFT     float64
# Open       AAPL     float64
#            AMZN     float64
#            GOOGL    float64
#            MSFT     float64
# Volume     AAPL       int64
#            AMZN       int64
#            GOOGL      int64
#            MSFT       int64
# dtype: object
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Checking the Columns of Amazon Data:-
#
# ...

# %%
# Step-3:- Handling Null/Missing Data:

print("Checking the missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#            Adj Close                       Close                        High  \
#                 AAPL   AMZN  GOOGL   MSFT   AAPL   AMZN  GOOGL   MSFT   AAPL
# Date
# 2013-11-25     False  False  False  False  False  False  False  False  False
# 2013-11-26     False  False  False  False  False  False  False  False  False
# 2013-11-27     False  False  False  False  False  False  False  False  False
# 2013-11-29     False  False  False  False  False  False  False  False  False
# 2013-12-02     False  False  False  False  False  False  False  False  False
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-11-17     False  False  False  False  False  False  False  False  False
# 2023-11-20     False  False  False  False  False  False  False  False  False
# 2023-11-21     False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# **It Seems like there is no null/missing value present in our combined_data_df**

# %%
# Step-4:- Handling Duplicates:

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df[combined_data_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-25    False
# 2013-11-26    False
# 2013-11-27    False
# 2013-11-29    False
# 2013-12-02    False
#               ...
# 2023-11-17    False
# 2023-11-20    False
# 2023-11-21    False
# 2023-11-22    False
# 2023-11-24    False
# Length: 2517, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# ...

# %% [markdown]
# **It Seems like there is no Duplicates value present in our combined_data_df**

# %% [markdown]
# **Our combined_data_df is now cleaned and ready for the other tasks.**

# %% [markdown]
# # Task-3:-
#
# **What was the change in stock price over time?**

# %%
# Step-1:- Viewing our combined_data_df before Concatenated our close value of every stock:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-25   16.398518   18.832001   26.174423   31.695011   18.705000
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2:- Now we are Concatenated all the close value of every stock: 

combined_data_df['Concatenated_Close'] = combined_data_df['Close',  'AAPL'].astype(int)  + combined_data_df['Close',  'AMZN'].astype(int)  + combined_data_df['Close', 'GOOGL'].astype(int)  + combined_data_df['Close',  'MSFT'].astype(int)

# %%
# Step-3:- Viewing our combined_data_df after Concatenated our close value of every stock:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-25   16.398518   18.832001   26.174423   31.695011   18.705000
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-4:- Now we are create a "Over Time" Column:

combined_data_df["Over_time"] = combined_data_df["Concatenated_Close"].diff()

# %%
# Step-5:- Now Viewing our combined_data_df after createing our "Over Time" Column:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-25   16.398518   18.832001   26.174423   31.695011   18.705000
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %% [markdown]
# # Task-4:-
#
# **Visualize the change in a stock’s volume being traded, over time?**

# %%
# Step-1:- Viewing the combined_data_df record Before Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-25   16.398518   18.832001   26.174423   31.695011   18.705000
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2:- Handling Null/Missing Data:

print("Checking the missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#            Adj Close                       Close                        High  \
#                 AAPL   AMZN  GOOGL   MSFT   AAPL   AMZN  GOOGL   MSFT   AAPL
# Date
# 2013-11-25     False  False  False  False  False  False  False  False  False
# 2013-11-26     False  False  False  False  False  False  False  False  False
# 2013-11-27     False  False  False  False  False  False  False  False  False
# 2013-11-29     False  False  False  False  False  False  False  False  False
# 2013-12-02     False  False  False  False  False  False  False  False  False
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-11-17     False  False  False  False  False  False  False  False  False
# 2023-11-20     False  False  False  False  False  False  False  False  False
# 2023-11-21     False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# **It shows here is a null/nan value present in our combined_data_df record after createing our Over time Column.**

# %%
# Step-3:- Droping the nan value present in our record:

combined_data_df.dropna(inplace=True)

# %%
# Step-4:- Now Replacing our Nan value with our mean value :

combined_data_df.fillna(combined_data_df.mean(), inplace=True)

# %%
# Step-5:- Viewing the combined_data_df record After Replacing with Nan Value: 

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# 2013-12-03   17.731712   19.233000   26.357859   32.259182   20.225714
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-6:- Now we are going to Visualize the change in a stock’s volume being traded over time:

import matplotlib.pyplot as plt
import pandas as pd

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(combined_data_df.index, combined_data_df['Volume'], marker='D',linestyle='-', color='b')
plt.title('Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True, color="r")

plt.show()

# %% [markdown]
# # Task-5:-
#
# **What was the moving average of various stocks?**

# %%
# Step-1:- Viewing our combined_data_df record Before Creating the moving average:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# 2013-12-03   17.731712   19.233000   26.357859   32.259182   20.225714
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2:- The moving average of various stocks are:

combined_data_df['10_Day_MA']=combined_data_df['Concatenated_Close'].rolling(window=10).mean()
combined_data_df['50_Day_MA']=combined_data_df['Concatenated_Close'].rolling(window=50).mean()

# %%
# Step-3:- Viewing our combined_data_df record After Creating the moving average:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# 2013-12-03   17.731712   19.233000   26.357859   32.259182   20.225714
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-4:- calculate null value present in our column "10-Day MA","50-Day MA":

print("Checking the missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#            Adj Close                       Close                        High  \
#                 AAPL   AMZN  GOOGL   MSFT   AAPL   AMZN  GOOGL   MSFT   AAPL
# Date
# 2013-11-26     False  False  False  False  False  False  False  False  False
# 2013-11-27     False  False  False  False  False  False  False  False  False
# 2013-11-29     False  False  False  False  False  False  False  False  False
# 2013-12-02     False  False  False  False  False  False  False  False  False
# 2013-12-03     False  False  False  False  False  False  False  False  False
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-11-17     False  False  False  False  False  False  False  False  False
# 2023-11-20     False  False  False  False  False  False  False  False  False
# 2023-11-21     False  False  False  False  False  False  False  False  False
# ...

# %%
# Step-5:- calculate Duplicates value present in our column "10-Day MA","50-Day MA":

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df[combined_data_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2013-11-26    False
# 2013-11-27    False
# 2013-11-29    False
# 2013-12-02    False
# 2013-12-03    False
#               ...
# 2023-11-17    False
# 2023-11-20    False
# 2023-11-21    False
# 2023-11-22    False
# 2023-11-24    False
# Length: 2516, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# ...

# %%
# Step-6:- Viewing the combined_data_df record Before Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2013-11-26   16.700970   19.068501   26.486736   31.450815   19.049999
# 2013-11-27   17.094231   19.335501   26.604355   31.661324   19.498571
# 2013-11-29   17.410784   19.681000   26.516266   32.107613   19.859644
# 2013-12-02   17.259233   19.615000   26.388388   32.377071   19.686787
# 2013-12-03   17.731712   19.233000   26.357859   32.259182   20.225714
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-7:- Droping the nan value present in our record:

combined_data_df.dropna(inplace=True)

# %%
# Step-8:- Now Replacing our Nan value with our Mode value :

combined_data_df.fillna(combined_data_df.mean(), inplace=True)

# %%
# Step-9:- Viewing the combined_data_df record After Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-07   16.368790   18.054001   29.465466   30.785578   18.559999
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %% [markdown]
# # Task-6:-
#
# **What was the daily return average of a stock?**

# %%
# Step-1:- Now Viewing our combined_data_df data before adding the daily return column:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-07   16.368790   18.054001   29.465466   30.785578   18.559999
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2:- Now Creating Daily Return column:

combined_data_df['Daily_Return'] = combined_data_df['Concatenated_Close'].pct_change() * 100

# %%
# Step-3:- Now Viewing our combined_data_df data After adding the daily return column:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-07   16.368790   18.054001   29.465466   30.785578   18.559999
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-4:- Droping the nan value present in our record:

combined_data_df.dropna(inplace=True)

# %%
# Step-5:- Now Replacing our Nan value with our mean value :

combined_data_df.fillna(combined_data_df.mean(), inplace=True)

# %%
# Step-6:- Viewing the combined_data_df record After Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %% [markdown]
# # Task-7:-
#
# **Add a new column ‘Trend’ whose values are based on the 'Daily Return'.**

# %%
# Step-1:- Now Viewing our combined_data_df before adding the Trend column:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2: Calculate the values of Trend over Daily Return.

combined_data_df["Trend"] = combined_data_df["Daily_Return"].diff()

# %%
# Step-3:- Now Viewing our combined_data_df before adding the Trend column:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %% [markdown]
# **It shows here is a null/nan value present in our combined_data_df after createing our Trend Column.**

# %%
# Step-4:- calculate null value present in our column Trend:

print("Checking the missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of missing values present in our Amazon Data:- \n")
print(combined_data_df.isnull().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the missing values present in our Amazon Data:-
#
#            Adj Close                       Close                        High  \
#                 AAPL   AMZN  GOOGL   MSFT   AAPL   AMZN  GOOGL   MSFT   AAPL
# Date
# 2014-02-10     False  False  False  False  False  False  False  False  False
# 2014-02-11     False  False  False  False  False  False  False  False  False
# 2014-02-12     False  False  False  False  False  False  False  False  False
# 2014-02-13     False  False  False  False  False  False  False  False  False
# 2014-02-14     False  False  False  False  False  False  False  False  False
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2023-11-17     False  False  False  False  False  False  False  False  False
# 2023-11-20     False  False  False  False  False  False  False  False  False
# 2023-11-21     False  False  False  False  False  False  False  False  False
# ...

# %%
# Step-5:- calculate Duplicates value present in our column Trend:

print("Checking the Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("Calculating the sum of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df.duplicated().sum())
print("\n\n----------------------------------------------------------------------------------------------------\n\n")

print("View of Duplicates values present in our Amazon Data:- \n")
print(combined_data_df[combined_data_df.duplicated() == True])
print("\n\n----------------------------------------------------------------------------------------------------\n\n")
# Out:
# Checking the Duplicates values present in our Amazon Data:-
#
# Date
# 2014-02-10    False
# 2014-02-11    False
# 2014-02-12    False
# 2014-02-13    False
# 2014-02-14    False
#               ...
# 2023-11-17    False
# 2023-11-20    False
# 2023-11-21    False
# 2023-11-22    False
# 2023-11-24    False
# Length: 2466, dtype: bool
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Calculating the sum of Duplicates values present in our Amazon Data:-
#
# 0
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# View of Duplicates values present in our Amazon Data:-
#
# Empty DataFrame
# ...

# %%
# Step-6:- Viewing the combined_data_df record Before Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-10   16.662041   18.043501   29.352604   30.987675   18.892500
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-7:- Droping the nan value present in our record:

combined_data_df.dropna(inplace=True)

# %%
# Step-8:- Now Replacing our Nan value with our Mode value :

combined_data_df.fillna(combined_data_df.mean(), inplace=True)

# %%
# Step-9:- Viewing the combined_data_df record After Replacing with Nan Value:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# 2014-02-18   17.197502   17.682501   30.302301   31.746027   19.499643
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %% [markdown]
# # Task-8:-
#
# **Visualize trend frequency through a Pie Chart.**

# %%
# Step-1:- Viewing the Trend columns before Changing the values:

combined_data_df['Trend']
# Out:
# Date
# 2014-02-11    1.980198
# 2014-02-12   -2.951072
# 2014-02-13    1.951266
# 2014-02-14   -0.980392
# 2014-02-18    0.000000
#                 ...
# 2023-11-17   -1.672257
# 2023-11-20    2.025101
# 2023-11-21   -2.373157
# 2023-11-22    2.128825
# 2023-11-24   -1.774503
# Name: Trend, Length: 2465, dtype: float64

# %%
# Step-2:- Now Changing the Trend columns value to "Stable", "Positive" and "Negative":

combined_data_df['Trend'] = 'Stable'
combined_data_df.loc[combined_data_df['Daily_Return'] > 0, 'Trend'] = 'Positive'
combined_data_df.loc[combined_data_df['Daily_Return'] < 0, 'Trend'] = 'Negative'

# %%
# Step-3:- Viewing the Trend columns after Changing the values:

combined_data_df['Trend']
# Out:
# Date
# 2014-02-11    Positive
# 2014-02-12    Negative
# 2014-02-13    Positive
# 2014-02-14      Stable
# 2014-02-18      Stable
#                 ...
# 2023-11-17    Negative
# 2023-11-20    Positive
# 2023-11-21    Negative
# 2023-11-22    Positive
# 2023-11-24    Negative
# Name: Trend, Length: 2465, dtype: object

# %%
# Step-2:- Visualize trend frequency through a Pie Chart:

# Calculate trend frequencies
trend_counts = combined_data_df['Trend'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%', startangle=140, shadow = True)

# Add a legend
plt.legend(trend_counts.index, title='Trends', loc='upper right')

# Add a title
plt.title('Trend Frequencies')

# Show the pie chart
plt.show()

# %% [markdown]
# # Task-9:-
#
# **What was the correlation between the daily returns of different stocks?**

# %% [markdown]
# To calculate the correlation between the daily returns of different stocks, you can use the pct_change() method to get the daily returns and then use the corr() method to calculate the correlation. Here's how you can do it:

# %%
# Step-1:- Viewing our combined_data_df before calculating the correlation:

combined_data_df
# Out:
#              Adj Close                                           Close  \
#                   AAPL        AMZN       GOOGL        MSFT        AAPL
# Date
# 2014-02-11   16.881584   18.089500   29.784285   31.299236   19.141430
# 2014-02-12   16.880316   17.462500   29.696947   31.551853   19.139999
# 2014-02-13   17.148369   17.860001   30.027529   31.669756   19.443930
# 2014-02-14   17.134501   17.867500   30.100100   31.678171   19.428213
# 2014-02-18   17.197502   17.682501   30.302301   31.746027   19.499643
# ...                ...         ...         ...         ...         ...
# 2023-11-17  189.690002  145.179993  135.309998  369.850006  189.690002
# 2023-11-20  191.449997  146.130005  136.250000  377.440002  191.449997
# 2023-11-21  190.639999  143.899994  136.970001  373.070007  190.639999
# 2023-11-22  191.309998  146.710007  138.490005  377.850006  191.309998
# 2023-11-24  189.669998  146.789795  136.592499  376.575012  189.669998
#
# ...

# %%
# Step-2:- Calculate the returns values for Calculate the correlation_matrix:

returns_values = combined_data_df['Adj Close'].pct_change()

# %%
# Step-3:-Calculate the correlation matrix:

correlation_matrix = returns_values.corr()

# %%
# Step-4:- viewing the correlation matrix:

correlation_matrix
# Out:
#            AAPL      AMZN     GOOGL      MSFT
# AAPL   1.000000  0.551226  0.610841  0.679598
# AMZN   0.551226  1.000000  0.649899  0.631039
# GOOGL  0.610841  0.649899  1.000000  0.716336
# MSFT   0.679598  0.631039  0.716336  1.000000

# %% [markdown]
# # The combined analysis of Stocks like:-
#
# -  **Apple**
# - **Google**
# - **Microsoft**
# - **Amazon**
#
# **Here is the end of combined analysis of Stocks.**

# %% [markdown]
# # Submitted by Biswakant Nayak
